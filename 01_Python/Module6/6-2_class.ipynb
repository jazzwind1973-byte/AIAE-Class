# %% [markdown]
# ##### Class 設計

# %%
# RPG遊戲角色

import random
import time

class Character:
    def __init__(self, name, hp, attack, defense):
        self.name =name
        self.hp = hp
        self.max_hp = hp
        self.attack_power = attack
        self.defense = defense

    def info(self):
        print(
            f"Name : {self.name}\n"
            f"HP   : {self.hp:>5}\n"
            f"ATK  : {self.attack_power:>5}\n"
            f"DEF  : {self.defense:>5}\n"
        )

    def attack(self, target):
        defense_value = random.randint(1, target.defense)
        damage = max(0, self.attack_power - defense_value)
        target.hp -= damage
        
        print(f"{self.name}攻擊{target.name}!造成傷害{damage}，剩餘血量 {target.hp}/{target.max_hp}")

    def is_alive(self):
        return self.hp > 0

hero = Character("Hero", 100, 20, random.randint(1, 10))
monster = Character("slime" ,50, 10, random.randint(1, 10))

hero.info()
monster.info()

while hero.is_alive() and monster.is_alive():
    hero.attack(monster)

    if monster.is_alive():
        monster.attack(hero)
    else:
        print(f"{hero.name}Win")
    if not hero.is_alive():
        print(f"{monster.name} Win")
    time.sleep(3)#間隔一秒
# Out:
# Name : Hero
# HP   :   100
# ATK  :    20
# DEF  :     2
#
# Name : slime
# HP   :    50
# ATK  :    10
# DEF  :     1
#
# Hero攻擊slime!造成傷害19，剩餘血量 31/50
# slime攻擊Hero!造成傷害8，剩餘血量 92/100
# Hero攻擊slime!造成傷害19，剩餘血量 12/50
# slime攻擊Hero!造成傷害8，剩餘血量 84/100
# Hero攻擊slime!造成傷害19，剩餘血量 -7/50
# HeroWin

# %%
import random
num = random.randint(1, 100)
print(num)
foods = ["便當", "漢堡", "三明治", "鹽酥雞", "小籠包"]
result = random.choice(foods)
print(result)

# %% [markdown]
# ##### 繼承

# %%
class Wizard(Character):
    def fireball(self, target):
        defense_value = random.randint(1, target.defense)
        damage = max(0, self.attack_power - defense_value)
        target.hp -= damage  
        print(f"{self.name}攻擊{target.name}!造成傷害{damage}，剩餘血量 {target.hp}/{target.max_hp}")
wizard = Wizard("法師", 80, 40,5)
monster = Character("slime", 50, 10, 3)
Wizard.fireball(monster)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 9
#       5         target.hp -= damage
#       6         print(f"{self.name}攻擊{target.name}!造成傷害{damage}，剩餘血量 {target.hp}/{target.max_hp}")
#       7 wizard = Wizard("法師", 80, 40,5)
#       8 monster = Character("slime", 50, 10, 3)
# ----> 9 Wizard.fireball(monster)
#
# TypeError: Wizard.fireball() missing 1 required positional argument: 'target'
