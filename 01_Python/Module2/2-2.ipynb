# %%
x = 10
print(x)
# Out:
# 10

# %%
# 往下新增 cell -> B
# 離開 cell -> Esc
# 刪除 cell -> x
# 執行 cell -> Crrl + Enter

# %%
name = "Javis"
print(name)
# Out:
# Javis

# %%
data = "True"
print(data)
# type()
print(type(data)) #查看該變數的資料型態
# Out:
# True
# <class 'str'>

# %%
#列表(list)
num = [ 1, 2, 3, 4]
print(nums)
print(type(nums))
# Out:
# {1, 2, 3, 4}
# <class 'set'>

# %%
#集合(set)

nums = {1, 2, 3, 4}
print(nums)
print(type(nums))
# Out:
# {1, 2, 3, 4}
# <class 'set'>

# %%
#字典(dict)
# (key: value)
user_info = {"name": "Jarvis", "age": 30}
print(user_info)
print(type(user_info))
# Out:
# {'name': 'Jarvis', 'age': 30}
# <class 'dict'>

# %%
data = []
print(data)
print(type(data))
# 創建一個空的 dict
data = {}
print(data)
print(type(data))
# Out:
# []
# <class 'list'>
# {}
# <class 'dict'>

# %%
1 # 打開終端機 -> Ctrl + `
2 # 換行 -> Ctrl + 上/下
3 # 切換畫面 -> Ctrl +<num>
4 # 切換分頁 -> Ctrl + Tab
5 # 打開檔案 -> Ctrl + PS
6 # 複製程式碼 -> Alt + shift + 上/下
7 # 同時修改多個同名變數 -> Ctrl + D
8 # 關閉檔案 ->Ctrl + W
9 # Vscode 當機處理方式 -> Ctrl + shift + P 輸入 reload windows 重新載入視窗
