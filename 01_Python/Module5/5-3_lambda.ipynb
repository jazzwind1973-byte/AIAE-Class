# %% [markdown]
# ### lambda 匿名函式
# 用法
#
# `lambda arguments: expression`

# %%
# 建立函式
def add_num1(x, y):
    return x + y

result = add_num1(100, 20)
print(result)
# Out:
# 120

# %%
# 基本用法
add_num2 = lambda x, y: x+y
# key = lambda x:x[2]
result = add_num2(100,20)
print(result)
# Out:
# 120

# %%
# 條件判斷
def check_even1(x):
    if x %2 == 0:
        return True
    else:
        return False

print(check_even1(10))
print(check_even1(5))
# Out:
# True
# False

# %%
check_even2 = lambda x: True if x % 2 == 0 else False
print(check_even2(10))
print(check_even2(5))

# %%
num = 20
#三元運算<if 結果>if<條件>else<else 結果>
result = True if num % 2 == 0 else False
print(result)

# %%
grade = 20
#三元運算<if 結果>if<條件>else<else 結果>
result = "及格" if grade >= 60 else "不及格"
print(result)
# Out:
# 不及格

# %%
# 多參數

# %% [markdown]
# ### 小試身手
# 請建立一個 list ，並在該 list 內產生多個 `[1, 2, x]` 的 list (x 的值要遞增)
# x 到 10 即可
# Ex :
# ```Python
# [ [1, 2, 1], [1, 2, 2], [1, 2, 3]...[1, 2, 10] ]
# ```

# %%
result=[]
for x in range(1,11):
    result.append([1,2,x])
print(result)

result = [[1, 2, i] for i in range(1,10)]
print(result)
# Out:
# [[1, 2, 1], [1, 2, 2], [1, 2, 3], [1, 2, 4], [1, 2, 5], [1, 2, 6], [1, 2, 7], [1, 2, 8], [1, 2, 9], [1, 2, 10]]

# %% [markdown]
# ##### `sort()` 方法

# %%
result=[]

# %% [markdown]
# 每三個 list 中間的值要改成 5
# Ex:
# ```python
# [ [1, 2, 1], [1, 2, 2], [1, 5, 3], [1, 2, 4], [1, 2, 5], [1, 5, 6]...]
# ```

# %%
result = []

for i in range(1, 11):
    if i % 3 == 0 :
        result.append([1, 5, i])
    else :
        result.append([1, 2, i])
print(result)

result.sort(reverse=True)
print(result)

result.sort(reverse=True, key=lambda x: x[2])
print(result)
# Out:
# [[1, 2, 1], [1, 2, 2], [1, 5, 3], [1, 2, 4], [1, 2, 5], [1, 5, 6], [1, 2, 7], [1, 2, 8], [1, 5, 9], [1, 2, 10]]
# [[1, 5, 9], [1, 5, 6], [1, 5, 3], [1, 2, 10], [1, 2, 8], [1, 2, 7], [1, 2, 5], [1, 2, 4], [1, 2, 2], [1, 2, 1]]
# [[1, 2, 10], [1, 5, 9], [1, 2, 8], [1, 2, 7], [1, 5, 6], [1, 2, 5], [1, 2, 4], [1, 5, 3], [1, 2, 2], [1, 2, 1]]
