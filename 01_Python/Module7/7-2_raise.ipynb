# %%
# 自訂例外處理
x = -10

if x <0:
    raise ValueError("資料不能小於0")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 5
#       1 # 自訂例外處理
#       2 x = -10
#       3
#       4 if x <0:
# ----> 5     raise ValueError("資料不能小於0")
#
# ValueError: 資料不能小於0

# %%
Cell in[1], lin5
    1 # 自訂例外處理
    2 x = -10
    3
    4 if x <0:
    5       raise ValueError("資料不能小於0")
    6
# Out:
#   Cell In[2], line 2
#     1 # 自訂例外處理
#     ^
# IndentationError: unexpected indent

# %%
# 自訂型別錯誤(TypeError)的例外處理
num = "五十"

if type(nums) ! = int:
    raise TypeError("只接受 int 的資料")
# Out:
#   Cell In[3], line 4
#     if type(nums) ! = int:
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##### 設計 raise 陳述

# %%
permission = "student"

if permission != "Admin":
    raise PermissionError("權限不足")
elif user_class not in ["AIPE01", "AIPE02", "AIPE03"]:
    raise ValueError("使用者非指定的學生")

return{"user","Jarvis", "user_class", "AIPE05"}

try:
    user_data = get_user_data("Admin", "BDDE36")
except Exception as e:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[7], line 4
#       1 permission = "student"
#       2
#       3 if permission != "Admin":
# ----> 4     raise PermissionError("權限不足")
#       5 elif user_class not in ["AIPE01", "AIPE02", "AIPE03"]:
#       6     raise ValueError("使用者非指定的學生")
#       7
#
# PermissionError: 權限不足
