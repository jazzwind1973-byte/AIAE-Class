# %% [markdown]
# # Mod 14 matplotlib 繪圖與視覺化
# > Matplotlib 是 Python 當中用來繪圖、圖表呈現及數據表示非常重要的一個 Package。Matplotlib 是一個功能強大的開源(Open Source) 工具包，用於表示及可視覺化數據

# %% [markdown]
# ## Simple plot

# %%
import matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# plt.style.use("ggplot")

# %% [markdown]
# ## array like

# %%
data0 = list(range(10))
data1 = np.arange(10, 1, -1)
data2 = pd.Series(range(0,10,2))

print(f'{data0}\n{data1}\n{data2}')
plt.plot(data0); plt.plot(data1); plt.plot(data2)

# %% [markdown]
# ## Grid / 中文顯示 / title / xlabel / ylabel / savefig
# > * `MS font` : SimHei, Bitstream Vera Sans, Lucida Grande, Verdana, Geneva, Lucid, Arial, Helvetica, Avant Garde, sans-serif, `Microsoft JhengHei`
# > * `IOS font` : 'Apple LiSung', 'Heiti TC'
#
# > * axes.unicode_minus : False 解決負號(-) 顯示為方塊的問題

# %% [markdown]
# # 確認電腦內部字型 `多半都不支援`

# %%
from matplotlib.font_manager import fontManager
for i in sorted(fontManager.get_font_names()):
    print(i, end=',    ')

# %%
# plt.style.use("ggplot")
plt.rcParams["font.family"] = ["Microsoft JhengHei"] # 正黑體
# plt.rcParams["font.family"] = ["Arial"] # 正黑體
plt.rcParams["axes.unicode_minus"] = False           # 可以顯示x, y 軸負數

X = np.linspace(-np.pi, np.pi, 25, endpoint=True)
S, C, T = np.sin(X), np.cos(X), np.tan(X)

plt.plot(X, S,'*')
plt.plot(X, C)
# plt.plot(X, T)

plt.title('this is title 這是標題')
plt.xlabel('x label(徑度)'), plt.ylabel('y label(值)')
plt.grid(alpha=.2)          # try plt.grid(axis='x')

plt.savefig(r'.\img\grid.jpg', dpi=150)  # 要寫在 plot show 之前
plt.savefig(r'.\img\grid.pdf', dpi=150, format='pdf')  # 要寫在 plot show 之前
plt.show()

# %% [markdown]
# > * Figure：可以把他當作畫布，一張畫布上可以有很多的 Axes。
# > * Axes：就是我們俗稱的「子圖」，每個 Axes 一次只能在一張畫布上。
# >><img src="./img/figure00.png">

# %% [markdown]
# >><img src="./img/figure01.png">

# %% [markdown]
# ## Figures and Subplots
# ><img src="./img/figure02.png"  style='width:90%'>

# %% [markdown]
# > * plt.plot｜繪圖的懶人包，會幫你直接在最近使用的圖表上繪圖，沒有的話就會自動新建一個。
# > * ax.plot｜手動建立的 API，提供多項客製化的參數與圖表控制。
# > * plt.tight_layout(rect=[0,0,1,1])參數數值詳解 [left, bottom, right, top]

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# plt.style.use("ggplot")

plt.figure(figsize=(8, 5))
# plt.subplot(n_rows, n_cols, plot_num)
plt.subplot(2, 2, 1)
plt.plot([0, 1], [0, 1])
plt.title('plt221')

plt.subplot(222)
plt.plot([1, 1], [0, 2])
plt.xlabel('222 x label')

plt.subplot(223)
plt.plot([2, 1], [3, 3])
plt.title('plt223')

plt.subplot(224)
plt.plot([4, 1], [1, 4])
plt.title('title224')

#tight_layout automatically adjusts subplot params so that the subplot(s) fits in to the figure area.
# plt.tight_layout()
plt.tight_layout(rect=[0, 0.0, 1, 1])

# %%
fig = plt.figure()  # figsize = (12,10)

# with no ID
# fig.add_subplot(2,1,1)
# fig.add_subplot(2, 2, 3)
# fig.add_subplot(224)

# with ID
ax1 = fig.add_subplot(221)
ax1.set_xlabel('x-label')
ax1.plot(X,S)
# ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 4)
ax3.set_xlabel('x3-label')
ax3.grid()
ax1.set_title('title')

# %% [markdown]
# <div style="page-break-after: always"></div>
#
# ## Color
# ><img src="./img/color.jpg"  style='width:80%'>

# %%
X = np.linspace(-np.pi, np.pi, 36, endpoint=True)
C, S = np.cos(X), np.sin(X)

plt.figure()
plt.plot(X, C)
plt.plot(X, S, color='r', lw=5)  # lw : line width
plt.plot(X+0.5, S, 'o', color='b')  # lw : line width

plt.show()

# %% [markdown]
# ## sup title

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.suptitle('sup title', size=16)
# plt.subplot(n_rows, n_cols, plot_num)
plt.subplot(2, 1, 1)
# figure splits into 2 rows, 1 col, plot to the 1st sub-fig
plt.plot([0, 1], [0, 1]); plt.title('plot1')

plt.subplot(234)
# figure splits into 2 rows, 3 col, plot to the 4th sub-fig
plt.plot([0, 1], [0, 2]); plt.title('plot2')

plt.subplot(235)
# figure splits into 2 rows, 3 col, plot to the 5th sub-fig
plt.plot([0, 1], [0, 3]); plt.title('plot3')

plt.subplot(236)
# figure splits into 2 rows, 3 col, plot to the 6th sub-fig
plt.plot([0, 1], [0, 4]); plt.title('plot4')

plt.show()

# %% [markdown]
# ## f, (ax1, ax2, ax3, ax4)

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(8,6))
# f, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(12,4))  # figsize 以英寸為單位指定圖形的寬度和高度
# plt.subplot(2, 2, 1)
ax1.plot([0, 1], [0, 1])  #(0,0) (1,1)

# plt.subplot(222)
ax2.plot([1, 1], [0, 2])

# plt.subplot(223)
ax3.plot([2, 1], [3, 3])

# plt.subplot(224)
ax4.plot([4, 1], [1, 4])
ax1.set_title('eeee')

# %% [markdown]
# ## Axis / Axes
# ### 大圖先畫

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(6, 5))
x = [1, 2, 3, 4, 5, 6, 7]
y = [1, 3, 4, 2, 5, 8, 6]

# below are all percentage
left, bottom, width, height = 0.1, 0.1, 0.8, 0.8
ax0 = fig.add_axes([left, bottom, width, height])  # main axes
ax0.plot(x, y, 'r'), ax0.set_xlabel('x'), ax0.set_ylabel('y')
ax0.set_title('ax0 title')

ax1 = fig.add_axes([0.2, 0.6, 0.25, 0.25])  # inside axes
ax1.plot(y, x, 'b'), ax1.set_xlabel('x'), ax1.set_ylabel('y')
ax1.set_title('ax1 title inside 1')

# different method to add axes
####################################
plt.axes([0.6, 0.2, 0.25, 0.25])
plt.plot(y[::-1], x, 'g'), plt.xlabel('x'), plt.ylabel('y')
plt.title('plt title inside 2')

plt.show()

# %% [markdown]
# ## x / y limit

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C,S = np.cos(X), np.sin(X)

# x limits
plt.xlim(X.min()*1.1, X.max()*1.1)
# y limits
plt.ylim(C.min()*1.1, C.max()*1.1)

plt.plot(X, C)
plt.plot(X, S, color='r', linewidth=10)

plt.show()

# %% [markdown]
# <div style="page-break-after: always"></div>
#
# ## x / y tick
# ><img src="./img/ticks.jpg"  style='width:100%'>

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)

plt.xlim(-4.0, 4.0)    # x limits
plt.xticks(np.linspace(-4, 4, 8, endpoint=False))    # x ticks
plt.ylim(-1.0, 1.0)     # y limits
plt.yticks(np.linspace(-1, 1, 5,endpoint=True))      # y ticks

plt.plot(X,C)
plt.plot(X,S, color='red', linewidth=10)

plt.show()

# %% [markdown]
# ## customize x / y tick

# %% [markdown]
# ## Latex
# $$ \frac{\partial^2}{\partial x_1\partial x_2}y$$
# $$-\pi$$

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C,  S = np.cos(X), np.sin(X)

# latex format
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.yticks([-1, 0, +1],
           [r'$-1$', r'$0$', r'$+1$'])

plt.plot(X,C)
plt.plot(X,S, color='red', linewidth=10)

plt.show()

# %% [markdown]
# ## Text & Annotation

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

# 繪製一個餘弦曲線
t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = ax.plot(t, s, lw=2)

# 繪製一個黑色，兩端縮排的箭頭
ax.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
            xycoords='data', arrowprops=dict(facecolor='r', shrink=0.05))
ax.text(1.0, 1.25, "Peak Value",fontsize=12, c='r')

ax.set_ylim(-2, 2)
plt.show()

# %% [markdown]
# # `練習 Q03 (1,2)`

# %% [markdown]
# ---
# # Mod 15 matplotlib 繪圖與視覺化

# %% [markdown]
# ## Line style
# ><img src="./img/lineStyle.jpg"  style='width:80%'>

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

color = 'cornflowerblue'

X = np.linspace(-np.pi, np.pi, 360, endpoint=True)
C = np.cos(X)

linestyles = ['-', '--', '-.', ':']

for x, linestyle in enumerate(linestyles):
    plt.plot(X, C+x, linestyle=linestyle, color=color, lw=3)
    
plt.show()

# %% [markdown]
# ## Marker
# ><img src="./img/marker.jpg"  style='width:100%'>
# https://matplotlib.org/stable/api/markers_api.html

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

color = 'cornflowerblue'

X = np.linspace(-np.pi, np.pi, 12, endpoint=True)
C = np.cos(X)

markers = ['o', 'v', '^', '<', '1']

for x, M in enumerate(markers):
    plt.plot(X, C+x, marker=M, color=color, linewidth=1)
    
plt.show()

# %% [markdown]
# <div style="page-break-after: always"></div>
#
# ## Legend (label)
# ><img src="./img/legend.jpg"  style='width:80%'>

# %% [markdown]
# > ### 引數 loc:
# 文字|數字
# :--:|:--:
# best        | 0
# upper right | 1
#  upper left | 2
#  lower left | 3
#  lower right | 4
#  right | 5 <br>(等同 'center right')
#  center left | 6
#  center right | 7
#  lower center | 8
#  upper center | 9
#  center | 10

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C,S = np.cos(X), np.sin(X)

plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
       [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.yticks([-1, 0, +1],
       [r'$-1$', r'$0$', r'$+1$'])

plt.plot(X, C, label='cosine', lw=1)                          # plot label
plt.plot(X, S, color='red', linewidth=2, label='sine') # plot label

# plt.legend(loc='upper right', frameon=True)
plt.legend(loc='best', frameon=1, shadow=1)

plt.show()

# %% [markdown]
# ## color, mark, line style
# |  |color   |  |mark           |      |line style
# --:|:-------|-:|:--------------|-----:|:--------
# b  |blue    |. |point          |  -   |solid
# g  |green   |o |circle         |  :   |dotted
# r  |red     |x |x-mark         |  -.  |dashdot
# c  |cyan    |+ |plus           |  --  |dashed
# m  |magenta |* |star           |(none)|no line
# y  |yellow  |s |square
# k  |black   |d |diamond
# w  |white   |v |triangle (down)
# |  |        |^ |triangle (up)
# |  |        |< |triangle (left)
# |  |        |> |triangle (right)
# |  |        |p |pentagram
# |  |        |h |hexagram

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [1, 4, 9, 16]
plt.plot(x, y, 'bo-')    # color, marker, lineStyle
# plt.plot(x, y, 'ro:')    # color, marker, lineStyle
plt.ylabel('y label')
plt.xlabel('x label')

plt.show()

# %% [markdown]
# ## plot 3D

# %%
import numpy as np
x = np.linspace(-4*np.pi, 4*np.pi, 50)
y = np.linspace(-4*np.pi, 4*np.pi, 50)

z = x**2 + y**2

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.plot(x,y,z)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bar chart

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

x = [4, 5, 6, 7, 8, 9]
y = [2, 10, 3, 2, 8, 7]
p=plt.bar(x, y, width=0.8)
plt.bar_label(p, padding=1, color='r')

plt.show()

# %% [markdown]
# ## Barh chart

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

x = ['sleep', 'study', 'play']
y = [2, 10, 3]
p = plt.barh(x, y, color='g')
plt.bar_label(p, padding=1, color='r')
plt.show()

# %% [markdown]
# ## Bar side by side

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
N = 5

men_means = (20, 35, 30, 35, 27)
women_means = (25, 32, 34, 20, 25)

ind = np.arange(N) 
width = 0.45      
M=plt.bar(ind, men_means, width, label='Men_means')
plt.bar_label(M, padding=1, color='b')

W=plt.bar(ind + width, women_means, width, label='Women_means')
plt.bar_label(W, padding=1, color='r')

plt.ylabel('Scores')
plt.title('Scores by group and gender')

plt.xticks(ind + width / 2, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## Bar stack

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

countries = ['USA', 'GB', 'China', 'Russia', 'Germany']
bronzes = np.array([38, 17, 26, 19, 15])
silvers = np.array([37, 23, 18, 18, 10])
golds = np.array([46, 27, 26, 19, 17])
ind = list(range(len(countries)))

print(ind)

g=plt.bar(ind, golds, width=0.8, label='golds', color='gold', bottom=silvers+bronzes)
plt.bar_label(g, padding=1, color='g')

s=plt.bar(ind, silvers, width=0.8, label='silvers', color='silver', bottom=bronzes)
plt.bar_label(s, padding=1, color='r')

b=plt.bar(ind, bronzes, width=0.8, label='bronzes', color='#CD853F')
plt.bar_label(b, padding=1, color='b')

plt.xticks(ind, countries)
plt.ylabel("Medals")
plt.xlabel("Countries")
plt.legend(loc="upper right")
plt.title("2012 Olympics Top Scorers")

plt.show()

# %% [markdown]
# ## Bar 3d

# %%
#importing the libraries
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = [8.00, 4.50]
plt.rcParams["figure.autolayout"] = True

fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')

x3 = [1, 3, 6, 9, 12, 15, 12, 8, 4, 10]
y3 = [6, 5, 8, 7, 5, 2, 3, 4, 6, 3]
z3 = np.zeros(10)
# z3 = np.full(1, 10)

dx = np.ones(10)
dy = np.ones(10)
dz = list(range(10))
# dz = [1, 3, 5, 2, 4, 8, 6, 7, 10, 9]

#plotting 3D bars
ax1.bar3d(x3, y3, z3, dx, dy, dz, color="yellow")
ax1.set_xlabel('x');   ax1.set_ylabel('y');   ax1.set_zlabel('z')

plt.show()

# %% [markdown]
# ## Scatter chart

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

x = np.array([4, 4, 7, 7, 8, 5])
y = np.array([2, 10, 3, 2, 8, 7])
# plt.scatter(x, y)
# plt.scatter(x, y, s=np.array(x)**5,  c=np.random.rand(len(y)))
plt.scatter(x, y)
plt.scatter(x+1, y+1, color='r', marker='*')

plt.show()

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
 
# Create data
N = 60
g1 = (0.6+0.6*np.random.rand(N), np.random.rand(N))
g2 = (0.4+0.3*np.random.rand(N), 0.5*np.random.rand(N))
g3 = (0.0+0.3*np.random.rand(N), 0.3*np.random.rand(N))

data = [g1, g2, g3]
colors = ["red", "green", "blue"]
groups = ["coffee", "tea", "water"]

for data, color, group in zip(data, colors, groups):
    x, y = data
    plt.scatter(x, y, alpha=0.9, c=color, edgecolors='none', s=30, label=group)

plt.legend(loc=2)
plt.title('Matplot scatter plot')
plt.show()

# %% [markdown]
# ## Scatter : boolean

# %%
x=np.random.randn(100); y=np.random.randn(100)

plt.figure(figsize=(12,4))
plt.subplot(121)
plt.scatter(x[x>0], y[x>0], color='red')    # x[x>0], y[x>0]
plt.scatter(x[x<=0], y[x<=0], color='blue')

plt.subplot(122)
plt.scatter(x[y>0], y[y>0], color='green')  
plt.scatter(x[y<=0], y[y<=0], color='yellow')

plt.show()

# %% [markdown]
# ## Scatter 3D

# %%
# 建立 3D 圖形
fig = plt.figure(figsize=(8,6))
# ax = fig.gca(projection='3d')
ax=fig.add_subplot(projection='3d')

# 產生 3D 座標資料
x1 = np.random.randn(50)+5
y1 = np.random.randn(50)+5
z1 = np.random.randn(50)+5
x2 = np.random.randn(50)
y2 = np.random.randn(50)
z2 = np.random.randn(50)

# 繪製 3D 座標點
ax.scatter(x1, y1, z1, c=z1, cmap='Reds', marker='^', label='My Points 1')
ax.scatter(x2, y2, z2, c=z2, cmap='Blues', marker='o', label='My Points 2')

# 顯示圖例
ax.legend()

# 顯示圖形
plt.show()

# %% [markdown]
# ## Histogram

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

x = [1, 17, 3, 24, 44, 5, 38, 21, 35, 26, 30, 27,23]
# plt.hist(x, bins=[0, 10, 20, 30, 40, 50])  # bins = integer : 等寬
plt.hist(x, bins=15, density=0)  # bins = integer : 等寬
# plt.hist(x, bins=[0, 10, 20, 30, 40, 50], cumulative=1)

plt.show()

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

## Generate gaussian number 
data = np.random.normal(2.0, 3.0, 100000)  # mean = 2.0, std = 3.0, number of points = 1000
a=plt.hist(data, bins=100)  # default bin = 10
plt.xlabel('Value'), plt.ylabel('Frequency'), plt.title('Histogram')
plt.show()
print(a)

# %% [markdown]
# ## Boxplot
# ><img src="./img/boxplot.jpg"  style='width:80%'>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import random
import numpy as np

value1= np.random.normal(50, 10, 200)  # how about loc=50, scale=10, size=200
value2= np.random.normal(60, 12, 200)
value3= np.random.normal(70, 12, 200)
value4= np.random.normal(40, 12, 200)

# value1.sort()
# print(f'sort value1 = {value1}\n{pd.DataFrame(value1).describe()}')

box_plot_data=[value1, value2, value3, value4]
plt.boxplot(box_plot_data, vert=1, patch_artist=True, 
            labels=['value1','value2','value3','value4'])
plt.show()

# %% [markdown]
# ## Pie chart

# %%
import matplotlib.pyplot as plt
 
labels = ['Cookies', 'Jellybean', 'Milkshake', 'Cheesecake']
sizes = [38.4, 40.6, 20.7, 10.3]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
patches, texts = plt.pie(sizes, 
                         colors=colors, 
                         shadow=True, 
                         startangle=90, 
                         labels=labels,
                         wedgeprops={'width': 0.5, 'edgecolor': 'white'})
plt.legend(patches, labels, loc="best");    plt.axis('equal')
plt.tight_layout()
output_file = './img/pie_chart01.png'
plt.savefig(output_file, dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
# ref: https://matplotlib.org/examples/pie_and_polar_charts/pie_demo_features.html
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 100]
explode = (0, 0, 0, 0.2)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.2f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.tight_layout()
output_file = './img/pie_chart02.png'
plt.savefig(output_file, dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Corr plot

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

# countries = ["china", "usa", "france", "russia",
# df = pd.read_csv("./datasets/titanic/train.csv")
df = pd.read_csv("./data/titanic.csv")
# print(f'{df.info()}\n\n'
#       f'df.head() :\n{df.head()}')
# print(df)

df=df.corr(method='pearson', numeric_only=True)
print(df)

fig, ax = plt.subplots(figsize=(8,8))
im = ax.imshow(df, interpolation='nearest')
fig.colorbar(im, orientation='vertical', fraction = 0.05)

ax.set_xticks(np.arange(len(df.columns)))
ax.set_xticklabels(df.columns)
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
ax.set_yticks(np.arange(len(df.index)))
ax.set_yticklabels(df.index)
for i in range(len(df.columns)):
    for j in range(len(df.index)):
        ax.text(j, i, df.iloc[i, j].round(2), ha="center", va="center", 
                color="w", fontsize=18)
ax.set_title("Corr")
plt.show()

# %% [markdown]
# ## add_patches

# %%
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(1, 1, 1)

rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.1)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]], color='r', alpha=0.1)

ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %%
year =np.arange(2002, 2010)
population = np.random.randint(25, 31, year.size)
img=plt.imread('./img/fruits.png')
img1=plt.imread('./img/parrot.jpeg')

plt.figure(figsize=(8,12))

plt.subplot(321)
plt.plot(year, population*1.5, color='red', marker='o')
plt.plot(year, population, color='blue', marker='o')
plt.title('Simple Plot')
plt.xlabel('year')
plt.ylabel('population')

plt.subplot(322)
plt.pie(population, autopct='%.2f %%')
# plt.show()

plt.subplot(323)
plt.bar(year, population)

plt.subplot(324)
plt.barh(year, population)

plt.subplot(325)
plt.imshow(img)

plt.subplot(326)
plt.imshow(img1)

plt.show()

# %% [markdown]
# # `練習 Q03 (3,4,5)`

# %% [markdown]
# ---
# <div style="page-break-after: always"></div>
#
# # 補充教材 : 3D, Pandas vs Matplotlib

# %% [markdown]
# ## 函式使用介紹：
# plot_surface(X, Y, Z, *args, **kwargs)
# > * X, Y, Z ：分別是三個代表 X, Y, Z 座標的 2D array
# > * cstride, rstride ：分別對應 column 與 row 方向的降採樣步伐，也就是繪圖的時候多少格要畫在同個網格內
# > * cmap ：Colormap，輸入一個字串對應一個3D surface的顏色
#
# colorbar(mappable, **kwargs)
# > * mappable ：colorbar 要加入的圖
# > * shrink ：控制 colorbar 的高度(預設為 1.0)
# > * aspect ：控制 colorbar 的寬高比(預設為 20)

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

# 建立 3D 圖形
fig = plt.figure(figsize=(10,5))
ax1 = fig.add_subplot(121, projection='3d')
ax2 = fig.add_subplot(122, projection='3d')

# 產生測試資料
X, Y, Z = axes3d.get_test_data(.05)

# 繪製 Wireframe 圖形
ax1.plot_wireframe(X, Y, Z, rstride=10, cstride=10, lw=.5)
ax2.plot_surface(X, Y, Z, cmap='seismic')

# 顯示圖形
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(121, projection='3d')
# ax = Axes3D(fig)
# X, Y value
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X ** 2 + Y ** 2)
# height value
Z = np.sin(R)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.get_cmap('rainbow'))

# I think this is different from plt12_contours
ax.contourf(X, Y, Z, zdir='z', offset=-2, cmap=plt.get_cmap('rainbow'))
ax.set_zlim(-2, 2)

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# plt.style.use('seaborn-whitegrid')

# %% [markdown]
# ## Line plot

# %%
# np.random.seed(12)
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range('1/1/2018', periods=1000))
ts, ts.plot.line()

# %%
ts.cumsum(), ts.cumsum().plot.line()

# %%
# On a DataFrame, the plot() method is a convenience to plot all of the columns with labels:
df = pd.DataFrame(
        np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"])
df = df.cumsum()
plt.figure()
df.plot()
plt.legend(loc='best'), df

# %%
df = pd.DataFrame({
    'name':['john','mary','peter','jeff','bill','lisa','jose'],
    'age':[23,78,22,19,45,33,20],
    'gender':['M','F','M','M','M','F','M'],
    'state':['california','dc','california','dc','california','texas','texas'],
    'num_children':[2,0,0,3,2,1,4],
    'num_pets':[5,1,0,5,2,2,3]
})
df, df.info()

# %% [markdown]
# ### ax = gca 返回當前圖窗中的當前座標區（或獨立視覺化）。使用 ax 獲取和設置當前座標區的屬性。如果當前圖窗中沒有座標區或圖，則 gca 會創建一個笛卡爾座標區物件。

# %%
df.plot()

# %%
# gca stands for 'get current axis'
ax = plt.gca()  # or create one ax

df.plot(kind='line', x='name', y='num_children', ax=ax)
df.plot(kind='line', x='name', y='num_pets', color='red', ax=ax)

plt.show()

# %%
df1 = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
                  columns=['A', 'B', 'C', 'D'],
                  index=np.arange(0, 100, 10))
df1, df1.plot(figsize=(8,4))

# %% [markdown]
# ## Bar plot

# %%
rng = np.random.RandomState(42)
df2 = pd.DataFrame(rng.randint(0,20, (5,4)), columns=['a', 'b', 'c', 'd'], 
                   index=['2001','2002','2003','2004','2005'])
df2.head(5)

# %%
df2.plot.bar();

# %%
df2.plot.bar(stacked=True);

# %%
df2.plot.barh(stacked=True);

# %%
df3 = df.groupby('state')['name'].nunique()

# %%
df, df3

# %%
# add title
plt.title('Number of records by State')
df3.plot(kind='bar');

# %%
# add y-axis label
plt.ylabel('records')
plt.ylim(0,4)

df3.plot(kind='bar', color='r');

# %% [markdown]
# ## Pie plot

# %%
np.random.seed(123456)
ss = pd.Series(3 * np.random.rand(4),
                    index=['a', 'b', 'c', 'd'], name='series')
ss

# %%
ss.plot.pie(figsize=(6, 6));

# %%
ss.plot.pie(labels=['AA', 'BB', 'CC', 'DD'], colors=['r', 'g', 'b', 'c'],
                   autopct='%.2f', fontsize=20, figsize=(6, 6));

# %%
raw_data = {'class_name': ['AIEN', 'BDSE', 'AIOT', 'SESE'],
        'Q1': [28, 24, 32, 18],
        'Q2': [25, 36, 20, 16],
        'Q3': [30, 34, 25, 23]}
cdf = pd.DataFrame(raw_data)
cdf

# %%
# Create a column with the total amount for each class
cdf['amt'] = cdf['Q1'] + cdf['Q2'] + cdf['Q3']
cdf, cdf[['class_name','amt']]

# %%
# Create pie chart
plt.pie(
    # using amt data
    cdf['amt'],
    # with the class name labels 
    labels=cdf['class_name'],
    # with one slide exploded out
    explode=(0, 0.15, 0, 0),
    # with the start angle at 90%
    startangle=90,
    # with the percent listed as a fraction
    autopct='%.2f%%'
    );

# %% [markdown]
# ## Histograms

# %%
df = pd.DataFrame({
    'name':['john','mary','peter','jeff','bill','lisa','jose'],
    'age':[23,78,22,19,45,33,20],
    'gender':['M','F','M','M','M','F','M'],
    'state':['california','dc','california','dc','california','texas','texas'],
    'num_children':[2,0,0,3,2,1,4],
    'num_pets':[5,1,0,5,2,2,3]
})
df

# %%
df['age'].plot(kind='hist', bins=[0,20,40,60,80,100], rwidth=0.8, legend=False)
# plt.show()

# %%
np.random.seed(123456)
df4 = pd.DataFrame({'a': np.random.randn(1000) + 1, 'b': np.random.randn(1000),
                    'c': np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])
df4

# %%
# Create a new figure
fig=plt.figure();

# %%
df4.plot.hist(alpha=.5);

# %%
df4.plot.hist(stacked=True, bins=10);

# %% [markdown]
# ## Scatter plot

# %%
# a scatter plot comparing num_children and num_pets
df.plot(kind='scatter',x='num_children',y='num_pets',color='red');

# %%
np.random.seed(123456)
df5 = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])

# %%
df5.head()

# %%
df5.plot.scatter(x='a', y='b', marker='^');

# %%
plt.plot(df5['c'], df5['d'], 'p', color='gray',
         markersize=10,
         markerfacecolor='white',   # face
         markeredgecolor='gray',    # edge
         markeredgewidth=2)         # edge width
plt.xlim(-0.1, 1.1);

# %% [markdown]
# ## Area plot

# %%
np.random.seed(123456)
df6 = pd.DataFrame(np.random.randint(0,30, (5,4)), columns=['a', 'b', 'c', 'd'])
df6

# %% [markdown]
# ### stacked = True

# %%
df6.plot.area()   # stacked = True

# %%
ax = df6.plot.area()
ax.legend(loc='upper center', ncol=2)
plt.ylim(0,70)
plt.plot();

# %%
ax = df6.plot.area(stacked=False)
ax.legend(frameon=True, shadow=True)   # legend frame
plt.plot();

# %%
x=np.arange(df6.shape[0])
x, df6

# %%
fig = plt.figure(figsize=(12,4))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)
ax1.stackplot(x, df6['a'], df6['b'])
ax2.stackplot(x, df6['c'], df6['d'], colors=['red','green']);

# %% [markdown]
# ## DataFrame plot

# %%
df = pd.read_csv('data/scores.csv')
df

# %%
df.Chi.plot.bar(); plt.show()
df.Eng.plot.bar(); plt.show()

# %%
df.groupby('Class').max()

# %%
df.groupby('Class').max().plot.bar()
plt.show()

df.groupby('Class').max().plot.bar(y=['Chi','Math'])
plt.show()

df.groupby('Class').max().plot.barh(y=['Eng','Math'], stacked=True)
plt.show()

df.groupby('Class').max().plot.bar(y=['Eng','Math'], subplots=True)
plt.show()

series = df['Class'].value_counts()
series.plot.pie(title='My Class', table=True, autopct='%.2f %%' ) # 百分比
plt.show()
