# %% [markdown]
# # Mod 06 Introducing `Series` Objects
# >* Pandas 在異質數據的讀取、轉換和處理上，都讓分析人員更容易處理，例如：從`列欄試算表`中找到想要的值。
# >* Pandas 提供兩種主要的資料結構，`Series 與 DataFrame`。Series 顧名思義就是用來處理序列相關的資料，主要為建立`索引的一維陣列`。DataFrame 則是用來處理結構化(Table like)的資料，有`列 row 索引與欄 column 標籤`的二維資料集，例如關聯式資料庫、CSV 等等。
# >* 透過載入至 Pandas 的資料結構物件後，可以透過結構化物件所提供的方法，來快速地進行`資料的前處理`，如資料補值，空值去除或取代......等。
# >* 更多的輸入來源及輸出整合性，例如：可以從`資料庫讀取資料進入` Dataframe，也可將處理完的資料`存回資料庫`。
#
# >><img src="./img/pandasDF02.png"  style='width:100%'>
# >><img src="./img/pandasDF01.png"  style='width:100%'>

# %%
import numpy as np
import pandas as pd
np.__version__, pd.__version__

# %% [markdown]
# ## 6-1 The Pandas Series Object
# > ### list vs. array vs. Series : `array like`
# > >><img src="./img/series01.png"  style='width:80%'>

# %%
# float
lst1 = [0.25, 0.5, -0.75, 1]      # list
np_array = np.array(lst1)         # array,    try reshape

ser1 = pd.Series(lst1)            # list to series
ser2 = pd.Series(np_array)        # array to series

print(f'lst1\t\t= {lst1}\n'
      f'np_array\t= {np_array}\n\n'
      f'ser1 =\n{ser1}\n\n'
      f'type(ser1) : {type(ser1)}\n\n'
      f'ser2 =\n{ser2}')

# %% [markdown]
# ## 6-2 boolean / logical & arithmetic operation

# %%
print(f'ser1 =\n{ser1}\n\n'
      f'ser1[ser1>0] =\n{ser1[ser1>0]}\n\n'
      f'ser1*2 =\n{ser1*2}\n\n'
      f'np.exp(ser1) =\n{np.exp(ser1)}')

# %% [markdown]
# ## 6-3 成員運算子(Membership Operators)

# %%
print(f'{ser1}\n\n'
      f'2 in ser1\t: {2 in ser1}\n'     # 2 is index, not value
      f'0.5 in ser1\t: {0.5 in ser1}')  # 1, 2 are indexes, not values

# %% [markdown]
# ### dtype : object

# %%
ser1 = pd.Series([0.25, 0.5, 'hello', 1.0])  # dtype : object
ser1, print(ser1)

# %% [markdown]
# ## 6-4 `Series` as generalized `NumPy array`
# ### index

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0], index=['a', 'c', 'b', 'd'])
# data = pd.Series([0.25, 0.5, 0.75, 1.0], index=list('acbd'))         # series 可以 index
data_np = np.array([0.25, 0.5, 0.75, 1.0])
print(f'data =\n{data}\n\n'
      f'data_np\t\t= {data_np}\n'
      f"data['b']\t= {data['b']}\n"
      f"data_np[2]\t= {data_np[2]}\n")

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0], index=[2, 5, 3, 7])   # index by numbers(str)
print(f'data =\n{data}\n\n'
      f'data[5] = {data[5]}')  # index代表 key like dictionary

# %% [markdown]
# ## 6-5 dict. to Series (key as index)

# %%
data = pd.Series({'A':'apple', 'B':'banana', 'C':'cherry'}) # like dictionary特殊化的字典, 但是它可支援陣列的運算 like slice
print(f"{data}\n\n"
      f"{data['A':'B']}")

# %% [markdown]
# ### `Series` as specialized `dictionary`

# %%
population_dict = {'California': 38332521, 'Texas': 26448193,     # a dictionary
                   'New York': 19651127, 'Florida': 19552860,
                   'Illinois': 12882135}
population = pd.Series(population_dict)
population

# %% [markdown]
# ### like dictionary

# %%
population['California'], population_dict['California']

# %% [markdown]
# ### slice : not for dict

# %%
print(f'{population}\n\n'
      f"{population['California':'New York']}")
# population.loc['California':'Illinois']

# %% [markdown]
# ## 6-6 Series Attributes

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0])
print(f'data =\n{data}\n\n'
      f'data.values\t= {data.values}\n'
      f'data.index\t= {data.index}\n'
      f'data.shape\t= {data.shape}\n'
      f'data.ndim\t= {data.ndim}\n'
      f'data.dtypes\t= {data.dtypes}\n'
      f'data.size\t= {data.size}\n'
      f'data.nbytes\t= {data.nbytes}')

# %% [markdown]
# ### index vs slice

# %%
print(f'data\t=\n{data}\n\n'
      f'data[1]\t= {data[1]}\n\n'
      f'data[1:3] =\n{data[1:3]}')

# %% [markdown]
# ### Axis Indexes with Duplicate Labels

# %%
obj = pd.Series(range(5), index=['a', 'a', 'b', 'b', 'c']) # index 可重複 no unique

# get all objects with index 'a'
print(f"{obj}\n\n{obj['a']}")

# %% [markdown]
# ### index.is_unique

# %%
# Check if index is unique
obj.index.is_unique  # it is attribut, don't need ()

# %% [markdown]
# ### Series name : column name in df
# 如果用於生成 DataFrame，則 Series 的名稱將成為其索引或列名稱。每當使用解釋器顯示 Series 時，也會使用它。

# %%
# Change Series name
data = pd.Series([0.25, 0.5, 0.75, 1.0, None, np.nan])
data.name = 'myseries'
data, pd.DataFrame(data), pd.DataFrame(data).columns

# %% [markdown]
# ## 6-7 loc 是 label, iloc 是 integer-location
# >### loc - `label` indexing 標籤索引 (標籤用)
# >### iloc - `positional` indexing 位置索引 (一定是 int 整數用)
# >><img src="./img/loc_iloc.jpg"  style='width:100%'>

# %% [markdown]
# ### loc

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0])

print(f'{data}\n\n'
      f'{data.loc[3]}\n\n'
      f'{data[1:3]}\n\n'   # position index
      f'{data.loc[1:3]}') # 包含 3

# %% [markdown]
# ### iloc

# %%
print(f'{data}\n\n'
      f'{data.iloc[3]}\n\n'
      f'{data[1:3]}\n\n'
      f'{data.iloc[1:3]}') # 不包含 3

# %% [markdown]
# ### index=['5','4','3','2']

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0], index=['5','4','3','2'])
print(f"{data}\n\n"
      f"{data.loc['3']}\n\n"
      f"{data['3':'5':-1]}\n\n"
      f"{data.loc['5':'3']}") # include 3

# %% [markdown]
# ### iloc

# %%
print(f'{data}\n\n'
      f'{data.iloc[3]}\n\n'
      f'{data.iloc[1:3]}') # 不包含 3

# %% [markdown]
# ### `iloc` 屬性允許進行索引和切片，它是引用 `隱式` Python 風格的索引：
# >><img src="./img/iloc01.png"  style='width:100%'>

# %%
data = pd.Series(['a','b','c'], index=[1,3,5] )
print(f'{data}\n\n'
      f'{data.iloc[1]}\n')

# %%
print(f'{data}\n\n'
      f'{data[1:3]}\n\n'
      f'{data.loc[1:3]}\n\n'
      f'{data.iloc[1:3]}') # 位置  slice

# %% [markdown]
# # `練習 Q02 (1,2)`

# %% [markdown]
# ---

# %% [markdown]
# # Mod 07 Getting Started with pandas

# %%
import pandas as pd
# from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 7-1 DataFrame
# >Pandas 是 Python 進行資料處理和資料分析一個好用的工具，其主要資料結構有包含：`Series 物件和 DataFrame 物件`。其中 DataFrame 就類似我們在使用的 `Excel 試算表`一樣，由欄列所組成的表格結構。由於 Pandas 本身基於 Numpy 所以在使用大量資料運算時效能表現也優於原生的 Python 資料結構，所以是常用將資料載入進行資料分析的好用工具。
#
# >> * Series 物件 : Series 為索引標籤和實際值的陣列組合
# >> * DataFrame 物件 : DataFrame 類似試算表和關聯式資料庫資料表（table）欄列結構，每一欄是`固定資料型別`但不同欄可以儲存不同的資料型別
#
# > 1. 就如 Table 表格,  多個 series, 共享相同的 index, 每個 series 可以不同的 Data Type
# > 2. `列索引與欄索引`  [row_indexer , col_indexer]  (列標籤索引與欄標籤索引)
# > 3. axis 方向很重要
# ><img src="./img/pandasDF.png"  style='width:100%'>
# ><img src="./img/pandasDF03.png"  style='width:100%'>

# %%
# it is a dictionary
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],     # dictionary
        'year': [2000, 2001, 2002, 2001, 2002, 2003],
        'popu': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
print(f"data :\n{data}\n\n"
      f"data['state'] : {data['state']}\n\n"
      f"{pd.DataFrame(data)}")
pd.DataFrame(data)['state']

# %% [markdown]
# ### df, df.T

# %%
df = pd.DataFrame(data, index=['d','f','f','h','j','k'])
print(f'{df}\n\n{df.T}')

# %% [markdown]
# ### attributes

# %%
print(f'df :\n{df}\n\n'
      f'df.index\t= {df.index}\n'
      f'df.columns\t= {df.columns}\n\n'
      f'df.values =\n{df.values}\n\n'
      f'type(df.values)\t= {type(df.values)}\n'
      f'df.ndim\t\t= {df.ndim}\n'
      f'df.shape\t= {df.shape}')

# %% [markdown]
# ### df observations

# %%
print(f'df :\n{df}\n\n'
      f'df.describe() :\n{df.describe()} end\n\n'  # state 不見了, why?
      f'df.info :\n{df.info()}\n\n'
      f'df.head(4) :\n{df.head(4)}\n\n'    # default top 5 rows
      f'df.tail(4) :\n{df.tail(4)}\n')

# %% [markdown]
# ### columns edit

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],     # dictionary
        'year': [2000, 2001, 2002, 2001, 2002, 2003],
        'popu': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}

pd.DataFrame(data, columns=['year', 'state', 'popu', 'nothing'])  # column 排列 add new column 'nothing'

# %% [markdown]
# ### df = Series + Series

# %%
area = pd.Series({'California': 423967, 'New York': 141297,'Texas': 695662,
                  'Florida': 170312, 'Illinois': 149995})
popu = pd.Series({'California': 38332521, 'Texas': 26448193,
                 'New York': 19651127, 'Florida': 19552860,
                 'Illinois': 12882135})
data = pd.DataFrame({'area':area, 'popu':popu})

print(f'data :\n{data}\n\n'
      f'data.area :\n{data.area}\n\n'
      f"data['area'] :\n{data['area']}\n\n"
      f'data.popu :\n{data.popu}\n\n'
      f"data['popu'] :\n{data['popu']}")
type(data['popu'])

# %% [markdown]
# ### new column

# %%
data['density'] = data['popu'] / data['area']
data.density = data.popu / data.area     # same
data

# %% [markdown]
# ### passing a single "index" to a ``DataFrame`` accesses a column:
# ### `a Sereis`

# %%
print(f"data['area'] :\n{data['area']}\n\n"
      f"data.area :\n{data.area}\n\n"
      f"data.area.ndim\t: {data.area.ndim}\n\n"
      f"type(data.area)\t: {type(data.area)}")   # Series

# %% [markdown]
# ### `a DataFrame`

# %%
print(f"{data[['area']]}\n\n"
      f"data[['area']].ndim : {data[['area']].ndim}\n\n"
      f"{type(data[['area']])}")    # DataFream

# %% [markdown]
# ### DataFrame 可 rename index & column name (Series 不能改變 index)

# %%
data1 = data.rename(columns={'area': 'Col_1'}, index={'California': 'Row_1'})
print(f'data :\n{data}\n\n'
      f'data rename data1 = \n{data1}')

# %% [markdown]
# ## 7-2 df slice

# %% [markdown]
# ### ``loc`` indexer slice

# %%
print(f'{data}\n\n'
      f"{data.loc['California':'New York',['area','density']]}\n")  # fancy index

# %%
data.loc['California':'New York','area':'density':2]  # slice (faster) skip 'popu'

# %%
print(f'{data}\n\n'
      f"{data.loc['Texas']}")

# %%
data.loc['Illinois', 'popu']

# %%
print(f'{data}\n\n'
      f"{data.loc[:'Texas', :'popu']}")   # 終點要算

# %% [markdown]
# ### 2d ``iloc`` indexer slice

# %%
print(f'data :\n{data}\n\n'
      f'data.iloc[1:4,[0,2]] :\n{data.iloc[1:4,[0,2]]}\n\n'      # fancy index
      f'data.iloc[1:4,::2] :\n{data.iloc[1:4,::2]}')   # silce (faster)

# %%
print(f'{data}\n\n'
      f'{data.iloc[0]}\n')  # row 0

# %%
print(f'{data}\n\n'
      f'{data.iloc[:3, :2]}')

# %%
print(f'{data}\n\n'
      f'{data.iloc[1, 2]}')  # [row, column]

# %% [markdown]
# ### combine masking & fancy indexing

# %%
print(f'{data}\n\n'
      f"{data.loc[data.density>100, ['popu', 'density']]}\n\n"
      f"{data.loc[data['density']>100, ['popu', 'density']]}\n\n"    # same as above
      f"{data.loc[data.density>100, 'popu':'density']}")          # same as above

# %% [markdown]
# ## 7-3 random sample : rows or [columns]
# > DataFrame.sample(n=None, frac=None, replace=False, weights=None, random_state=None, axis=None)

# %%
# s1 = pd.Series(range(10, 15), ind_char)
s1 = pd.DataFrame(np.arange(50).reshape(-1, 5),  
                   columns=['Ohio', 'Texas', 'California', 'illinos', 'New York'])
print(s1, '\n')
s1['New York']=s1['New York'].apply(lambda x:1 if x<25 else 2)
s1

# %% [markdown]
# ### replace = True : 抽樣完放回

# %%
print(f'frac=.6 :\n{s1.sample(frac=.6)}\n\n'   # replace =1, replace = False
      f'n=5, axis=0, replace=True, random_state=2 :\n{s1.sample(n=5, axis=0, replace=True, random_state=2)}\n\n'
      f'frac=.6, axis=1 :\n{s1.sample(frac=.6, axis=1)}\n\n'
      f'frac=2, replace=True :\n{s1.sample(frac=2, replace=True)}')   # frac =2, replace=True

# %% [markdown]
# ### build train and test sets

# %%
train = s1.sample(frac=.7)
test = s1.drop(train.index)
print(f's1 :\n{s1}\n\n'
      f'train :\n{train}\n\n'
      f'test :\n{test}')

# %% [markdown]
# ### sklearn.model_selection.train_test_split
# ><img src="./img/stratified.png"  style='width:100%'>

# %%
from sklearn.model_selection import train_test_split
y = s1['New York']
# s1.drop(['New York'],axis=1, inplace=True)
X_train, X_test, y_train, y_test = train_test_split(s1.iloc[:,:-1], y, test_size=0.3, 
                                                    random_state=None, stratify=y)  # stratify
print(f'X_train :\n{X_train}\n\n'
      f'y_train :\n{y_train}\n\n'
      f'X_test :\n{X_test}\n\n'
      f'y_test :\n{y_test}')

# %% [markdown]
# ---

# %% [markdown]
# # Mod 08 Essential Functionality
# ><img src="./img/func.jpg" style='width:100%'>

# %% [markdown]
# ## 8-1 Reindexing

# %%
import pandas as pd
import numpy as np
obj = pd.Series([4.5, 7.2, -5.3, 3.6], index=['d', 'b', 'a', 'c'])
obj

# %%
obj2 = obj.reindex(['a', 'b', 'c', 'd', 'e'])  # e NaN
obj2

# %% [markdown]
# ### reindex, ffill/ bfill

# %%
obj3 = pd.Series(['blue', 'purple', 'yellow', 'red'], index=[0, 2, 3, 5])
print(f"obj3 :\n{obj3}\n\n"
      f"obj3.reindex(range(10), method='ffill' :\n{obj3.reindex(range(10), method='ffill')}\n\n"    
      f"obj3.reindex(range(10), method='bfill' :\n{obj3.reindex(range(10), method='bfill')}\n")

# %% [markdown]
# ### reindex NaN

# %%
frame = pd.DataFrame(np.arange(9).reshape((3, 3)),
                     index=['a', 'c', 'd'],
                     columns=['Ohio', 'Texas', 'California'])
frame2 = frame.reindex(['a', 'b', 'c', 'd'])    # row reindex
print(f'frame :\n{frame}\n\n'
      f'frame2 :\n{frame2}')

# %%
states = ['Texas', 'Utah', 'California']
frame, frame.reindex(columns=states)

# %% [markdown]
# ### Indexing with a DataFrame's columns

# %%
frame = pd.DataFrame({'a': range(7), 'b': range(7, 0, -1),
                      'c': ['one', 'one', 'one', 'two', 'two', 'two', 'two'],
                      'd': [0, 1, 2, 0, 1, 2, 3]})
frame

# %%
frame2 = frame.set_index(['c'])  # drop c
frame2

# %%
frame.set_index(['c'], drop=False)  # don't drop column c

# %%
frame2.reset_index()  # back to original

# %% [markdown]
# ## 8-2 Dropping Entries from an Axis
# > axis : {0 or 'index', 1 or 'columns'}<br>
# > default 0<br>
# > Whether to drop labels from the index (0 or 'index') or columns (1 or 'columns').

# %% [markdown]
# ### drop inplace = False

# %%
import pandas as pd
import numpy as np
obj = pd.Series([4.5, 7.2, -5.3, 3.6], index=['d', 'b', 'a', 'c'])
obj

# %%
obj = pd.Series(np.arange(5.), index=['a', 'b', 'c', 'd', 'e'])
print(f"{obj}\n\n"
      f"{obj.drop('c')}\n\n"
      f"{obj.drop(['d', 'c'])}\n\n"
      f"{obj}")   # no inplace

# %% [markdown]
# ### drop inplace = True

# %%
obj = pd.Series(np.arange(5.), index=['a', 'b', 'c', 'd', 'e'])
print(obj, '\n')
obj.drop('c', inplace=True)
obj

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
                    index=['Ohio', 'Colorado', 'Utah', 'New York'],
                    columns=['one', 'two', 'three', 'four'])
data

# %% [markdown]
# ### inplace = False / True

# %%
data.drop(['Colorado', 'Ohio'], inplace=False), data

# %%
data.drop('two', axis=1), data.drop(['two', 'four'], axis='columns')

# %% [markdown]
# ## 8-3 Arithmetic and Data Alignment

# %%
df1 = pd.DataFrame(np.arange(9.).reshape((3, 3)), columns=list('bcd'),
                   index=['Ohio', 'Texas', 'Colorado'])
df2 = pd.DataFrame(np.arange(12.).reshape((4, 3)), columns=list('bde'),
                   index=['Utah', 'Ohio', 'Texas', 'Oregon'])
df1, df2

# %%
df1 + df2

# %% [markdown]
# ### Arithmetic methods with fill values

# %%
df1 = pd.DataFrame(np.arange(12.).reshape((3, 4)), columns=list('abcd'))
df2 = pd.DataFrame(np.arange(20.).reshape((4, 5)), columns=list('abcde'))
df2.loc[1, 'b'] = np.nan
df1, df2

# %%
df1 + df2

# %% [markdown]
# ## 8-4 Function Application and Mapping

# %%
import pandas as pd
import numpy as np
frame = pd.DataFrame(np.random.randn(4, 3), columns=list('bde'),
                     index=['Utah', 'Ohio', 'Texas', 'Oregon'])
frame, np.abs(frame), np.abs(frame.b)

# %% [markdown]
# ### apply (default row axis=0)

# %%
# frame, frame.apply(np.cumsum)
print(frame, '\n\n', frame.b.apply(lambda x: x+10),'\n\n')

# %% [markdown]
# ### Sorting and Ranking

# %%
obj = pd.Series(range(4), index=['D', 'a', 'c', 'b'])
obj, obj.sort_index()

# %%
frame = pd.DataFrame(np.arange(12).reshape((3, 4)),
                     index=['three', 'one', 'four'],
                     columns=['d', 'a', 'b', 'c'])
print(f'{frame}\n\n'
      f'{frame.sort_index()}\n\n'
      f'{frame.sort_index(axis=1)}\n\n'
      f'{frame.sort_index().sort_index(axis=1)}')

# %%
frame, frame.sort_index(axis=1, ascending=False)

# %%
obj = pd.Series([4, 7, -3, 2])
obj, obj.sort_values()

# %%
obj = pd.Series([4, np.nan, 7, np.nan, -3, 2])
obj.sort_values()

# %%
frame = pd.DataFrame({'b': [4, 7, -3, 2], 'a': [0, 1, 0, 1]})
frame, frame.sort_values(by='b') # by column 'b'

# %%
frame.sort_values(by=['a', 'b'])  # 'a' first, 'b' second

# %% [markdown]
# # `練習 Q02 (3,4,5)`

# %% [markdown]
# ---

# %% [markdown]
# # Mod 09 Data Cleaning and Preparation
# > ## missing values
# ><img src="./img/data_missing.jpg" style='width:100%'>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 9-1 Handling Missing Data
# ><img src="./img/dropna01.png" style='width:80%'>
# ><img src="./img/drop01.png" style='width:80%'>

# %% [markdown]
# ### np.nan / hasnans, isnull

# %%
data = pd.Series(['banana', 'orange', np.nan, 'avocado'])
print(f'data =\n{data}\n\n'
      f'hasnans = {data.hasnans}\n\n'
      f'notnull = \n{data.notnull()}\n\n'
      f'isnull =\n{data.isnull()}')

# %% [markdown]
# ### Filtering Out Missing Data
# #### import nan

# %%
from numpy import nan
data = pd.Series([1, nan, 3.5, nan, 7])
data, data.dropna()

# %%
data, data[data.notnull()]

# %%
data = pd.DataFrame([[1., 6.5, 3.], [1., nan, nan],
                     [nan, nan, nan], [nan, 6.5, 3.]])
cleaned = data.dropna()
print(f'{data}\n\n'
      f'{cleaned}')

# %%
data, data.dropna(how='all')

# %%
data[4] = nan    # column 4
data, data.dropna(axis=1, how='all')  # axis = 1 column

# %% [markdown]
# ## 一個 row（橫列）或 column（直欄）裡面，有效數值（非 NaN）的數量必須 $\ge$ thresh，它才`不會`被丟掉。

# %%
df = pd.DataFrame(np.random.randn(7, 3))
df.iloc[:4, 1] = nan
df.iloc[:2, 2] = nan
df.iloc[4, :] = nan
print(f'{df}\n\n'
      f'{df.dropna()}\n\n'
      f'{df.dropna(thresh=2)}')      # drop >=2 NaN and above

# %% [markdown]
# ### Filling In Missing Data
# ><img src="./img/fill01.png" style='width:100%'>

# %%
df = pd.DataFrame(np.random.randn(7, 3))
df.iloc[:4, 1] = nan
df.iloc[:2, 2] = nan
df, df.fillna(0)

# %%
df, df.fillna({1: 0.5, 2: 0})  # 1:, 2: columns

# %% [markdown]
# ### inplace

# %%
df1 = df.fillna(0, inplace=True)
df, df1  # inplace fill in df

# %% [markdown]
# ### ffill

# %%
df = pd.DataFrame(np.random.randn(6, 3))
df.iloc[2:, 1] = nan
df.iloc[4:, 2] = nan
print(df)
# df.fillna(method='ffill'), df.fillna(method='ffill', limit=1)
df.ffill(), df.ffill(limit=1)

# %% [markdown]
# ### fill mean. median

# %%
data = pd.Series([1., np.nan, 3.5, np.nan, 7])

data, pd.concat([data, data.fillna(data.mean()), data.fillna(data.median())], axis=1)

# %% [markdown]
# ### fill interpolation 有時間序

# %%
import pandas as pd
import numpy as np
s = pd.Series([0, 1, np.nan, np.nan, np.nan, 3, np.nan, np.nan, np.nan, 10])

pd.concat([s, s.interpolate(), s.interpolate(method='polynomial', order=2)], axis=1)

# %% [markdown]
# ## 09-2 Data Transformation

# %% [markdown]
# ### Removing Duplicates
# ><img src="./img/duplicate01.png" style='width:100%'>

# %%
import pandas as pd
data = pd.DataFrame({'k1': ['one', 'two'] * 3 + ['two'],
                     'k2': [1, 1, 2, 3, 3, 4, 4]})
data

# %%
data.duplicated().any()

# %% [markdown]
# ### 完全重複

# %%
data.duplicated(), data.duplicated().sum()  # 完全重複

# %%
data, data.drop_duplicates()

# %% [markdown]
# ### keep = 'first'

# %%
data['v1'] = range(7)
data, data.drop_duplicates(['k1'])

# %% [markdown]
# ### keep='last', False

# %%
data, data.drop_duplicates(['k1', 'k2'], keep='last')  # 留最後下一筆, try False kill all

# %% [markdown]
# ## 9-3 Replacing Values

# %%
data = pd.Series([1., -999., 2., -999., -1000., 3.])
data

# %%
data.replace(-999, np.nan)

# %%
data, data.replace([-999, -1000], np.nan)

# %%
# both are same
data, data.replace([-999, -1000], [np.nan, 0]), data.replace({-999: np.nan, -1000: 0})

# %% [markdown]
# ## 9-4 Discretization and Binning
# ### cut 以`值 value` 來切
# ><img src="./img/cut01.png" style='width:100%'>

# %%
ages = [12, 18, 20, 28, 25, 27, 21, 23, 37, 31, 61, 45, 41, 32]

bins = [18, 25, 35, 60, 100]
cats = pd.cut(ages, bins)
cats

# %%
print(cats.codes, '\n')
print(cats.categories, '\n')
print(cats.value_counts())

# %%
group_names = ['Youth', 'YoungAdult', 'MiddleAged', 'Senior']
print(f'ages\t : {ages}\n\n'
      f'bins\t : {bins}\n\n'
      f'pd.cut\t :\n{pd.cut(ages, bins, labels=group_names)}')

# %% [markdown]
# ### q_cut 等份 `比例`來切

# %%
data = np.random.randn(1000)  # Normal distributed
cats = pd.qcut(data, 4, labels=['Q1', 'Q2', 'Q3', 'Q4'])  # Cut into quartiles
print(f'data[:20] :\n{data[:20]}\n\n'
      f'cats :\n{cats}\n\n'
      f'cats.codes[:50] :\n{cats.codes[:50]}\n\n'
      # f'pd.value_counts(cats) :\n{pd.value_counts(cats)}')
      f'pd.value_counts(cats) :\n{cats.value_counts()}')

# %% [markdown]
# ### unequal inteval / 不等份 `比例`來切

# %%
cats = pd.qcut(data, [0, 0.1, 0.5, 0.9, 1.], precision=5)
print(f'{data[:20]}\n\n'
      f'{cats}\n\n'
      # f'{pd.value_counts(cats)}')
      f'{cats.value_counts()}')

# %% [markdown]
# ---

# %% [markdown]
# # Mod 10 資料彙總和分組 Data Aggregation & Group Operations
#
# 函數    | 描述
# ------:|-------------
# mean() | 計算各組的平均值
# sum()   | 計算各組值的總和
# size()  | 計算各組的大小
# count() | 計算各組的數量
# std()   | 計算各組的標準差
# var()   | 計算各組的方差
# sem()   | 計算各組平均值的標準誤差
# describe() | 產生描述性統計信息
# first() | 計算各組值的第一個值
# last()  | 計算各組值的最後一個值
# nth()   | 取第 n 個值，如果 n 是列表，則取其子集
# min()   | 計算各組值的最小值
# max()   | 計算各組值的最大值

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 11-1 df aggregation
# > 對於 DataFrame，`預設`情況下，聚合函數傳回每個 `axis=0` 欄位的結果。

# %%
rng = np.random.RandomState(42)
df = pd.DataFrame({'A': rng.rand(5), 'B': rng.rand(5)})

print(f'df =\n{df}\n\n'
      f'df.count() =\n{df.count()}\n\n'
      f'df.mean() =\n{df.mean()}\n\n'
      f'df.median() =\n{df.median()}\n\n'
      f'df.min() =\n{df.min()}\n\n'
      f'df.max() =\n{df.max()}\n\n'
      f'df.std() =\n{df.std()}\n\n'
      f'df.quantile(.5) =\n{df.quantile(.5)}')

# %% [markdown]
# ### agg function vs. describe
# > agg 返回的也是一個DataFrame。很多功能用 sum、mean 等等也可以實現。但是 agg 更加簡潔, 而且傳給它的函數可以是字串，也可以自訂，參數是column對應的子DataFrame。

# %%
print(f"df.agg('mean') :\n{df.agg('mean')}\n{'-'*60}\n"
      f"df.agg(['count', 'mean', 'std', 'min', 'max'] :\n{df.agg(['count', 'mean', 'std', 'min', 'max'])}\n{'-'*60}\n"
      f'df.describe() :\n{df.describe()}')

# %%
print(f'df :\n{df}\n{"-"*60}\n'
      f"df.mean(axis='columns') :\n{df.mean(axis='columns')}\n{'-'*60}\n"
      f'df.mean(axis=1) :\n{df.mean(axis=1)}')

# %% [markdown]
# ## 10-2 Series 彙總  & 排序

# %%
ser1 = pd.Series([1, 2, 3, 4, 5, 6, 6, 7, 8, 9, 20, 30, 40, 50, 60])
print (f'ser1.sum()\t= {ser1.sum()}\n'
       f'ser1.min()\t= {ser1.min()}\n'
       f'ser1.max()\t= {ser1.max()}\n'
       f'ser1.mean()\t= {ser1.mean()}\n'
       f'ser1.count()\t= {ser1.count()}\n'
       f'ser1.median()\t= {ser1.median()}\n'
       f'ser1.mode()\t= {ser1.mode()[0]}\n'
       f'ser1.std()\t= {ser1.std()}')

# %%
print (f'ser1.describe() =\n{ser1.describe()}\n\n'
       f'ser1.max()- ser1.min() = {ser1.max()- ser1.min()}\n\n'     # 最高和最低差多少 (統計 全距)
       f'ser1.agg(["mean", "sum", "min", max"]) =\n{ser1.agg(["mean", "sum", "min", "max"])}\n') # agg = aggregate

# %% [markdown]
# ### df.columns (a Sereis)

# %%
import numpy as np
import pandas as pd
rng = np.random.RandomState(42)
df = pd.DataFrame({'A': rng.rand(5), 'B': rng.rand(5)})

print(f'df =\n{df}\n\n'
      f'A.mean \t\t= {df.A.mean()}\n'
      f'B.median()\t= {df["B"].median()}\n'  #df.B = df["B"]
      f'A.min\t\t= {df.A.min()}\n'
      f'B.max\t\t= {df.B.max()}\n'
      f'A.std\t\t= {df.A.std()}')

# %% [markdown]
# ## 10-3 GroupBy Mechanics
# > 用 groupby 進行資料分組，可以看做是基於行（或者說是index）操作的話，則 agg 函數則是基於`列`的聚合操作。
#
# > groupby 返回的是一個 DataFrameGroupBy 結構，這個結構必須調用彙總函式（如sum）之後，才會得到結構為 Series 的資料結果。用 groupby 函數後，要接類似 sum、mean 等彙總函式才能輸出
#
# ><img src="./img/groupby.jpg"  style='width:100%'>

# %%
df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'],
                   'key2' : ['one', 'two', 'one', 'two', 'one'],
                   'data1' : np.random.randn(5),
                   'data2' : np.random.randn(5)})
df

# %%
grouped = df['data1'].groupby(df['key1'])
grouped  # object 物件

# %%
grouped.mean(), grouped.sum()

# %%
means = df['data1'].groupby([df['key1'], df['key2']]).mean()
df, means

# %% [markdown]
# <center><h1>--- The End ---</h1></center>
