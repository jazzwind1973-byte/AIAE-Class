# %% [markdown]
# ## 1.  請寫 "姓名" 在繳交作業的檔名上
# ## 2.  請將作業答案跑出結果, 存檔後寄出, 檔案請不要壓縮
# ## 3.  預計課程結束後 二週內交作業
# ## email 到 : jungan0914@gmail.com

# %% [markdown]
# # HW_numpy

# %%
import numpy as np
import numpy.ma as ma
import matplotlib.pyplot as plt
# 股價範例
                 
price = np.array([3120, 568, 210, 78, 819, 89])              # list 股價                                        
s_name = np.array(['DLK', 'TCD', 'KYA', 'QDA', 'MTK', 'TWP']) # list 股票公司代號

# 1. 股價總和為多少 ? 

# 2. 股票公司 總共有幾家 ? 

# 3. 股價最高是多少 ? 是哪一家公司 ?

# 4. 股價最低是多少 ? 是哪一家公司 ?

# 5. 股價中位數是多少 ? ?

# 6. list 股價大於 500 的公司,  股價分別是多少 ?

# 7. 除了 TCD 公司以外的 股價 總是多少 ?


# 8. 畫兩子圖看 price 分佈狀況
#    0. 要建 共用 title (Stock Price), 字型大小 16
#    1. bar 圖  (要分別有 title, xlabel, ylabel, legend, grid)
#    2. pie 圖  (要分別有 title, 標註 %)

# %% [markdown]
# # HW pandas & plt

# %%
import numpy as np; import csv
import pandas as pd
# 搜尋 班級學生成績
# Read scores.csv
df = pd.read_csv('../data/scores.csv')
df

# 1. 共幾個 學員成績 ?						




# 2. 找出 平均前三名 的學員所有科目成績




# 3. 找出 後面兩名 的學員所有科目成績					




# 4. 找出 ID 'aaa','bbb','ccc' 的學員國文英文科目成績




# 5. 找出學員 'bbb' 的成績	                          ==




# 6. 找出除了 'bbb' 學員的學員的所有成績 ('bbb' 退學)	!=
         
    

# 7. 找出 'aaa', 'bbb' 'ccc' 學員 國文數學兩科 科目成績  |	 isin(...)	



# 8. 數學不及格 ... 是誰 ?



# 9. 用 彙總 agg 的函數算出 各科的' count', 'mean', 'min', 'max', 'std'




# 10.

# %% [markdown]
# # 加分題

# %%
# 將下列兩 list 兩 list 作一 bar chart (x : s_name, y : price),  bar chart 的 bar 必須由大到小排列
# 並將每一個 bar 的上方顯示 values

# -------- your code -------------------------
